# %%
import pandas as pd

# %%
var = '...'
var += " "*(5 - len(var)%5)

# %%
df = pd.DataFrame(columns = ['2', '3', '4', '5', '1'])

# %%
start = index = 0
for stop in range(5, len(var) + 1, len(df.columns)):
    try:
        df.loc[index] = [char for char in var[start:stop]]
        
        print('working' ,index, var[start:stop])
        start  = stop
        index += 1 
    except:
        pass
# Out:
# working 0 cnnbu
# working 1 sines
# working 2 smicr
# working 3 osoft
# working 4 hasas
# working 5 oluti
# working 6 onfor
# working 7 thefa
# working 8 milia
# working 9 rprob
# working 10 lemof
# working 11 needi
# working 12 ngtor
# working 13 ememb
# working 14 ertoo
# working 15 manyp
# working 16 asswo
# working 17 rdsdo
# working 18 ingaw
# working 19 aywit
# working 20 hthem
# working 21 altog
# working 22 ether
# working 23 theco
# working 24 mpany
# working 25 annou
# working 26 ncedw
# working 27 ednes
# working 28 dayth
# working 29 atitw
# working 30 illin
# working 31 trodu
# working 32 ceapa
# working 33 sswor
# working 34 dless
# working 35 accou
# working 36 ntopt
# working 37 ionto
# working 38 rallu
# working 39 serso
# working 40 fseve
# working 41 ralpo
# working 42 pular
# working 43 servi
# working 44 cessu
# working 45 chasm
# working 46 icros
# working 47 oftou
# working 48 tlook
# working 49 andmi
# working 50 croso
# working 51 ftone
# working 52 drive
# ...

# %%
df
# Out:
#      2  3  4  5  1
# 0    c  n  n  b  u
# 1    s  i  n  e  s
# 2    s  m  i  c  r
# 3    o  s  o  f  t
# 4    h  a  s  a  s
# ..  .. .. .. .. ..
# 445  d  t  o  t  y
# 446  p  e  o  u  t
# 447  a  p  a  s  s
# 448  w  o  r  d  j
# 449  u  s  t  y  e
#
# [450 rows x 5 columns]

# %%
# df = pd.DataFrame([string], columns=['string_values'])

# %%
df
# Out:
#      2  3  4  5  1
# 0    c  n  n  b  u
# 1    s  i  n  e  s
# 2    s  m  i  c  r
# 3    o  s  o  f  t
# 4    h  a  s  a  s
# ..  .. .. .. .. ..
# 445  d  t  o  t  y
# 446  p  e  o  u  t
# 447  a  p  a  s  s
# 448  w  o  r  d  j
# 449  u  s  t  y  e
#
# [450 rows x 5 columns]

# %%
# List of Tuples
users = [ ('Shivam', 'Pandey', 'India'),
             ('Kumar', 'Ram' , 'India' ),
              ]
#Create a DataFrame object
df3 = pd.DataFrame(  users, 
                    columns = ['First Name' , 'Last Name', 'Country'],
                    index=['a', 'b']) 


print('Dataframe before adding a new row:\n')
print('---------------------------------------\n')
print(df3)

df3.loc['c'] = ['Vikram', 'Aruchamy', 'India']

print('\nDataframe after adding a new row:\n')
print('---------------------------------------\n')

print(df3)
df3.loc['d'] = ['c', 'n', 'n']
# Out:
# Dataframe before adding a new row:
#
# ---------------------------------------
#
#   First Name Last Name Country
# a     Shivam    Pandey   India
# b      Kumar       Ram   India
#
# Dataframe after adding a new row:
#
# ---------------------------------------
#
#   First Name Last Name Country
# a     Shivam    Pandey   India
# b      Kumar       Ram   India
# c     Vikram  Aruchamy   India

# %%
df3.loc['e'] = [char for char in var[:3]]

# %%
[char for char in var[:3]]
# Out:
# ['c', 'n', 'n']

# %%
df3
# Out:
#   First Name Last Name Country
# a     Shivam    Pandey   India
# b      Kumar       Ram   India
# c     Vikram  Aruchamy   India
# d          c         n       n
# e          c         n       n

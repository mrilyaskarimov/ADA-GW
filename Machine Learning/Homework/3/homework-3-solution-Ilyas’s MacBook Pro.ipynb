# %% [markdown]
# # CSCI 6364 ML Homework 3 Submission

# %% [markdown]
# **Group Members:**
#
# - Aydin Bagiyev (abagiyev@gwu.edu)
# - Narmin Jamalova (njamalova54@gwu.edu)
# - Ilyas Karimov (ilyaskarimov@gwu.edu)

# %% [markdown]
# ## Importing Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import export_text
import matplotlib.pyplot as plt
from sklearn import tree
import pandas as pd
import numpy as np

pd.set_option("max_columns", None)

# %% [markdown]
# ## Reading the Data

# %%
df_original = pd.read_csv("../datasets/mental-heath-in-tech-2016_20161114.csv")
df_original.head()
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                1.0
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                    Not eligible for coverage / N/A
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                                Yes
#
#   Do you know the options for mental health care available under your employer-provided coverage?  \
# 0                                                NaN
# 1                                                Yes
# 2                                                NaN
# 3                                                NaN
# 4                                                Yes
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#   Does your employer offer resources to learn more about mental health concerns and options for seeking help?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                                NaN
# 4                                                 No
#
#   If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:  \
# 0                                          Very easy
# 1                                      Somewhat easy
# 2                         Neither easy nor difficult
# 3                                                NaN
# 4                         Neither easy nor difficult
#
#   Do you think that discussing a mental health disorder with your employer would have negative consequences?  \
# 0                                                 No
# 1                                                 No
# 2                                              Maybe
# 3                                                NaN
# 4                                                Yes
#
#   Do you think that discussing a physical health issue with your employer would have negative consequences?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                              Maybe
#
#   Would you feel comfortable discussing a mental health disorder with your coworkers?  \
# 0                                              Maybe
# 1                                              Maybe
# 2                                              Maybe
# 3                                                NaN
# 4                                              Maybe
#
#   Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?  \
# 0                                                Yes
# 1                                                Yes
# 2                                              Maybe
# 3                                                NaN
# 4                                                 No
#
#   Do you feel that your employer takes mental health as seriously as physical health?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                                NaN
# 4                                                 No
#
#   Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#    Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                1.0
# 4                                                NaN
#
#   Do you know local or online resources to seek help for a mental health disorder?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                Yes, I know several
# 4                                                NaN
#
#   If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                          Sometimes, if it comes up
# 4                                                NaN
#
#   If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                       I'm not sure
# 4                                                NaN
#
#   If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                          Sometimes, if it comes up
# 4                                                NaN
#
#   If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                       I'm not sure
# 4                                                NaN
#
#   Do you believe your productivity is ever affected by a mental health issue?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                Yes
# 4                                                NaN
#
#   If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              1-25%
# 4                                                NaN
#
#    Do you have previous employers?  \
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
#
#   Have your previous employers provided mental health benefits?  \
# 0                                       No, none did
# 1                                  Yes, they all did
# 2                                       No, none did
# 3                                           Some did
# 4                                       I don't know
#
#   Were you aware of the options for mental health care provided by your previous employers?  \
# 0                          N/A (not currently aware)
# 1                                I was aware of some
# 2                          N/A (not currently aware)
# 3                          N/A (not currently aware)
# 4                          N/A (not currently aware)
#
#   Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?  \
# 0                                       I don't know
# 1                                           None did
# 2                                           None did
# 3                                           None did
# 4                                           Some did
#
#   Did your previous employers provide resources to learn more about mental health issues and how to seek help?  \
# 0                                           None did
# 1                                           Some did
# 2                                           Some did
# 3                                           None did
# 4                                           None did
#
#   Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?  \
# 0                                       I don't know
# 1                                        Yes, always
# 2                                       I don't know
# 3                                       I don't know
# 4                                       I don't know
#
#   Do you think that discussing a mental health disorder with previous employers would have negative consequences?  \
# 0                                       Some of them
# 1                                       None of them
# 2                                       I don't know
# 3                                       Some of them
# 4                                       Some of them
#
#   Do you think that discussing a physical health issue with previous employers would have negative consequences?  \
# 0                                       None of them
# 1                                       None of them
# 2                                       Some of them
# 3                                       Some of them
# 4                                       Some of them
#
#   Would you have been willing to discuss a mental health issue with your previous co-workers?  \
# 0                      Some of my previous employers
# 1               No, at none of my previous employers
# 2                      Some of my previous employers
# 3                      Some of my previous employers
# 4               No, at none of my previous employers
#
#   Would you have been willing to discuss a mental health issue with your direct supervisor(s)?  \
# 0                      Some of my previous employers
# 1                      Some of my previous employers
# 2                                       I don't know
# 3                      Some of my previous employers
# 4                      Some of my previous employers
#
#   Did you feel that your previous employers took mental health as seriously as physical health?  \
# 0                                       I don't know
# 1                                           Some did
# 2                                       I don't know
# 3                                       I don't know
# 4                                           Some did
#
#   Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?  \
# 0                                       None of them
# 1                                       None of them
# 2                                       Some of them
# 3                                       Some of them
# 4                                       Some of them
#
#   Would you be willing to bring up a physical health issue with a potential employer in an interview?  \
# 0                                              Maybe
# 1                                              Maybe
# 2                                                Yes
# 3                                                Yes
# 4                                              Maybe
#
#                                      Why or why not?  \
# 0                                                NaN
# 1  It would depend on the health issue. If there ...
# 2  They would provable need to know, to Judge if ...
# 3  old back injury, doesn't cause me many issues ...
# 4  Depending on the interview stage and whether I...
#
#   Would you bring up a mental health issue with a potential employer in an interview?  \
# 0                                              Maybe
# 1                                                 No
# 2                                                Yes
# 3                                              Maybe
# 4                                                 No
#
#                                    Why or why not?.1  \
# 0                                                NaN
# 1  While mental health has become a more prominen...
# 2                                   Stigma, mainly.
# 3  would not if I was not 100% sure that the disc...
# 4                                       I don't know
#
#   Do you feel that being identified as a person with a mental health issue would hurt your career?  \
# 0                                              Maybe
# 1                         No, I don't think it would
# 2                                              Maybe
# 3                              Yes, I think it would
# 4                              Yes, I think it would
#
#   Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?  \
# 0                       No, I don't think they would
# 1                       No, I don't think they would
# 2                                              Maybe
# 3                                              Maybe
# 4                                              Maybe
#
#   How willing would you be to share with friends and family that you have a mental illness?  \
# 0                                      Somewhat open
# 1                                      Somewhat open
# 2                                      Somewhat open
# 3                                            Neutral
# 4                                      Somewhat open
#
#   Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?  \
# 0                                                 No
# 1                                                 No
# 2                                     Maybe/Not sure
# 3                                                 No
# 4                                 Yes, I experienced
#
#   Have your observations of how another individual who discussed a mental health disorder made you less likely to reveal a mental health issue yourself in your current workplace?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                NaN
# 4                                                Yes
#
#   Do you have a family history of mental illness?  \
# 0                                              No
# 1                                             Yes
# 2                                              No
# 3                                              No
# 4                                             Yes
#
#   Have you had a mental health disorder in the past?  \
# 0                                                Yes
# 1                                                Yes
# 2                                              Maybe
# 3                                                Yes
# 4                                                Yes
#
#   Do you currently have a mental health disorder?  \
# 0                                              No
# 1                                             Yes
# 2                                              No
# 3                                             Yes
# 4                                             Yes
#
#   If yes, what condition(s) have you been diagnosed with?  \
# 0                                                NaN
# 1  Anxiety Disorder (Generalized, Social, Phobia,...
# 2                                                NaN
# 3  Anxiety Disorder (Generalized, Social, Phobia,...
# 4  Anxiety Disorder (Generalized, Social, Phobia,...
#
#   If maybe, what condition(s) do you believe you have?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Have you been diagnosed with a mental health condition by a medical professional?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
#
#    If so, what condition(s) were you diagnosed with?  \
# 0  Anxiety Disorder (Generalized, Social, Phobia,...
# 1  Anxiety Disorder (Generalized, Social, Phobia,...
# 2                                                NaN
# 3  Anxiety Disorder (Generalized, Social, Phobia,...
# 4  Anxiety Disorder (Generalized, Social, Phobia,...
#
#    Have you ever sought treatment for a mental health issue from a mental health professional?  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#   If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?  \
# 0                               Not applicable to me
# 1                                             Rarely
# 2                               Not applicable to me
# 3                                          Sometimes
# 4                                          Sometimes
#
#   If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?  \
# 0                               Not applicable to me
# 1                                          Sometimes
# 2                               Not applicable to me
# 3                                          Sometimes
# 4                                          Sometimes
#
#    What is your age? What is your gender? What country do you live in?  \
# 0                 39                 Male               United Kingdom
# 1                 29                 male     United States of America
# 2                 38                Male                United Kingdom
# 3                 43                 male               United Kingdom
# 4                 43               Female     United States of America
#
#   What US state or territory do you live in? What country do you work in?  \
# 0                                        NaN               United Kingdom
# 1                                   Illinois     United States of America
# 2                                        NaN               United Kingdom
# 3                                        NaN               United Kingdom
# 4                                   Illinois     United States of America
#
#   What US state or territory do you work in?  \
# 0                                        NaN
# 1                                   Illinois
# 2                                        NaN
# 3                                        NaN
# 4                                   Illinois
#
#   Which of the following best describes your work position?  \
# 0                                 Back-end Developer
# 1             Back-end Developer|Front-end Developer
# 2                                 Back-end Developer
# 3                               Supervisor/Team Lead
# 4  Executive Leadership|Supervisor/Team Lead|Dev ...
#
#   Do you work remotely?
# 0             Sometimes
# 1                 Never
# 2                Always
# 3             Sometimes
# 4             Sometimes

# %% [markdown]
# ## Inspecting the Columns

# %%
# list all columns available
print(list(df_original.columns))
# Out:
# ['Are you self-employed?', 'How many employees does your company or organization have?', 'Is your employer primarily a tech company/organization?', 'Is your primary role within your company related to tech/IT?', 'Does your employer provide mental health benefits as part of healthcare coverage?', 'Do you know the options for mental health care available under your employer-provided coverage?', 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?', 'Does your employer offer resources to learn more about mental health concerns and options for seeking help?', 'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?', 'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:', 'Do you think that discussing a mental health disorder with your employer would have negative consequences?', 'Do you think that discussing a physical health issue with your employer would have negative consequences?', 'Would you feel comfortable discussing a mental health disorder with your coworkers?', 'Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?', 'Do you feel that your employer takes mental health as seriously as physical health?', 'Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?', 'Do you have medical coverage (private insurance or state-provided) which includes treatment of \xa0mental health issues?', 'Do you know local or online resources to seek help for a mental health disorder?', 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?', 'If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?', 'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?', 'If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?', 'Do you believe your productivity is ever affected by a mental health issue?', 'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?', 'Do you have previous employers?', 'Have your previous employers provided mental health benefits?', 'Were you aware of the options for mental health care provided by your previous employers?', 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?', 'Did your previous employers provide resources to learn more about mental health issues and how to seek help?', 'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?', 'Do you think that discussing a mental health disorder with previous employers would have negative consequences?', 'Do you think that discussing a physical health issue with previous employers would have negative consequences?', 'Would you have been willing to discuss a mental health issue with your previous co-workers?', 'Would you have been willing to discuss a mental health issue with your direct supervisor(s)?', 'Did you feel that your previous employers took mental health as seriously as physical health?', 'Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?', 'Would you be willing to bring up a physical health issue with a potential employer in an interview?', 'Why or why not?', 'Would you bring up a mental health issue with a potential employer in an interview?', 'Why or why not?.1', 'Do you feel that being identified as a person with a mental health issue would hurt your career?' ...

# %%
# print the count of values for each column
for col in df_original.columns:
    print("Column: ", col)
    print(df_original[col].value_counts(dropna=False).to_dict())
# Out:
# Column:  Are you self-employed?
# {0: 1146, 1: 287}
# Column:  How many employees does your company or organization have?
# {'26-100': 292, nan: 287, 'More than 1000': 256, '100-500': 248, '6-25': 210, '500-1000': 80, '1-5': 60}
# Column:  Is your employer primarily a tech company/organization?
# {1.0: 883, nan: 287, 0.0: 263}
# Column:  Is your primary role within your company related to tech/IT?
# {nan: 1170, 1.0: 248, 0.0: 15}
# Column:  Does your employer provide mental health benefits as part of healthcare coverage?
# {'Yes': 531, "I don't know": 319, nan: 287, 'No': 213, 'Not eligible for coverage / N/A': 83}
# Column:  Do you know the options for mental health care available under your employer-provided coverage?
# {nan: 420, 'No': 354, 'I am not sure': 352, 'Yes': 307}
# Column:  Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?
# {'No': 813, nan: 287, 'Yes': 230, "I don't know": 103}
# Column:  Does your employer offer resources to learn more about mental health concerns and options for seeking help?
# {'No': 531, "I don't know": 320, 'Yes': 295, nan: 287}
# Column:  Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?
# {"I don't know": 742, 'Yes': 320, nan: 287, 'No': 84}
# Column:  If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:
# {nan: 287, 'Somewhat easy': 281, 'Very easy': 220, 'Somewhat difficult': 199, 'Neither easy nor difficult': 178, "I don't know": 150, 'Very difficult': 118}
# Column:  Do you think that discussing a mental health disorder with your employer would have negative consequences?
# {'Maybe': 487, 'No': 438, nan: 287, 'Yes': 221}
# Column:  Do you think that discussing a physical health issue with your employer would have negative consequences?
# {'No': 837, nan: 287, 'Maybe': 268, 'Yes': 41}
# Column:  Would you feel comfortable discussing a mental health disorder with your coworkers?
# {'Maybe': 479, 'No': 392, nan: 287, 'Yes': 275}
# Column:  Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?
# {'Yes': 428, 'Maybe': 382, 'No': 336, nan: 287}
# Column:  Do you feel that your employer takes mental health as seriously as physical health?
# {"I don't know": 493, 'Yes': 350, 'No': 303, nan: 287}
# Column:  Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?
# {'No': 1048, nan: 287, 'Yes': 98}
# Column:  Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues?
# {nan: 1146, 1.0: 185, 0.0: 102}
# Column:  Do you know local or online resources to seek help for a mental health disorder?
# {nan: 1146, 'I know some': 141, 'Yes, I know several': 83, "No, I don't know any": 63}
# Column:  If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?
# {nan: 1146, 'Not applicable to me': 101, 'No, because it would impact me negatively': 83, 'Sometimes, if it comes up': 57, "No, because it doesn't matter": 44, 'Yes, always': 2}
# Column:  If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?
# {nan: 1289, "I'm not sure": 66, 'No': 42, 'Yes': 36}
# Column:  If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?
# {nan: 1146, 'Not applicable to me': 111, 'Sometimes, if it comes up': 99, 'No, because it would impact me negatively': 51, "No, because it doesn't matter": 15, 'Yes, always': 11}
# Column:  If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?
# {nan: 1146, 'Not applicable to me': 133, "I'm not sure": 62, 'No': 57, 'Yes': 35}
# Column:  Do you believe your productivity is ever affected by a mental health issue?
# {nan: 1146, 'Yes': 204, 'Unsure': 38, 'Not applicable to me': 31, 'No': 14}
# Column:  If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?
# {nan: 1229, '1-25%': 92, '26-50%': 72, '51-75%': 26, '76-100%': 14}
# Column:  Do you have previous employers?
# {1: 1264, 0: 169}
# Column:  Have your previous employers provided mental health benefits?
# {'Some did': 391, 'No, none did': 372, "I don't know": 313, 'Yes, they all did': 188, nan: 169}
# Column:  Were you aware of the options for mental health care provided by your previous employers?
# {'N/A (not currently aware)': 582, 'I was aware of some': 384, 'Yes, I was aware of all of them': 181, nan: 169, 'No, I only became aware later': 117}
# Column:  Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?
# {'None did': 890, 'Some did': 255, nan: 169, "I don't know": 86, 'Yes, they all did': 33}
# Column:  Did your previous employers provide resources to learn more about mental health issues and how to seek help?
# {'None did': 842, 'Some did': 371, nan: 169, 'Yes, they all did': 51}
# Column:  Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?
# {"I don't know": 860, nan: 169, 'Yes, always': 164, 'No': 121, 'Sometimes': 119}
# Column:  Do you think that discussing a mental health disorder with previous employers would have negative consequences?
# {'Some of them': 615, "I don't know": 310, 'Yes, all of them': 226, nan: 169, 'None of them': 113}
# Column:  Do you think that discussing a physical health issue with previous employers would have negative consequences?
# {'Some of them': 631, 'None of them': 559, nan: 169, 'Yes, all of them': 74}
# Column:  Would you have been willing to discuss a mental health issue with your previous co-workers?
# {'Some of my previous employers': 740, 'No, at none of my previous employers': 430, nan: 169, 'Yes, at all of my previous employers': 94}
# Column:  Would you have been willing to discuss a mental health issue with your direct supervisor(s)?
# {'Some of my previous employers': 654, 'No, at none of my previous employers': 416, nan: 169, "I don't know": 101, 'Yes, at all of my previous employers': 93}
# Column:  Did you feel that your previous employers took mental health as seriously as physical health?
# {'None did': 463, 'Some did': 427, "I don't know": 331, nan: 169, 'Yes, they all did': 43}
# Column:  Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?
# {'None of them': 758, 'Some of them': 444, nan: 169, 'Yes, all of them': 62}
# Column:  Would you be willing to bring up a physical health issue with a potential employer in an interview?
# {'Maybe': 633, 'No': 441, 'Yes': 359}
# Column:  Why or why not?
# {nan: 338, "I don't know": 3, 'Fear of discrimination': 3, 'Not relevant': 3, 'bias': 2, 'Fear of not getting the job': 2, 'None of their business.': 2, 'honesty': 2, "I don't want it held against me": 1, "It would only hurt your chances of being hired. And if you don't get hired you'll wonder for the rest of your life if that affected it": 1, "It depends on the issue and how it affects the job. If it was 100% unnecessary I'd keep it to myself.": 1, 'I would hope that it would let me know whether I would fit in at this employer based off of their reaction.': 1, "I have a physical disability that is not visible. If I don't bring it up, it will make itself known down the line. Better to bring it up when I am in control of the situation, than to call in sick and surprise the employer. This also affect insurance policy, so keeping it hidden doesn't work out so well.": 1, "I would not want to work for an employer that reacted negatively to a physical health issue. I think it's a good test to ensure that they're the kind of employer I'd want to work for. ": 1, 'if it affected the ability for someone to preform their job.': 1, 'It is what it is. If that causes a problem, I should not work there.': 1, 'only if it impacts work': 1, 'Depends on the issue, how it affected my work or responsibilities.': 1, 'I would have to read the room, it would  depend on how much i feel an employer expects of me.': 1, 'not his concern': 1, 'bias. a lack of understanding.': 1, 'Depends, if it affected the job then yes I would talk about it. ': 1, 'i would do it if it makes me unable to perform certain tasks (cannot be exposed to certain liquids, heavy things lifting, etc)': 1, 'I feel physical injuries are more acceptable now.': 1, "I decide this based on my feelings towards my counterpart. If I feel that the interviewer is a kind human beeing I'll bring it up. Otherwise I don't.": 1, 'It should not affect the outcome. ': 1, 'Unless it would affect my ability to perform my duties my health is of no relevance to my employer.': 1, 'Like all interviews, I feel like not putting your "best foot" forward puts you at a disadvantage.': 1, 'Depending on the interview stage and whether I required an accommodation, I would': 1, 'Health benefits are expensive and few business hire someone they know will cost them a lot.': 1, "It's relevant.": 1, 'To be up front about any factors that may affect my work performance. ': 1, 'It would depend on the position (on-site vs remote) and even then on the "vibe" with the interviewer, if I felt a low risk of bringing up the topic.': 1, 'it might impact the services they needed to provide': 1, "It's a market, it would devalue the offering stupid": 1, 'Transparency': 1, 'Risk of losing consideration for a position ': 1, "If I believe it would be relevant to the job I'm interviewing for (if I would need some kind of accommodation for my issue).  Otherwise, I think it would reduce my chances of being hired.": 1, 'It depends on how permanent the issue is likely to be.': 1, "Physical health for the most part doesn't get in the way of my job directly.": 1, 'Some physical health has stigma attached, other does not.': 1, 'It would depend on the job requirements and expectations': 1, "If I felt it was important, I wouldn't feel it was likely that there would be any negative effect from sharing this.": 1, "Chronic physical health issues often affect hiring decisions, even though employers won't say so.  I'm diabetic, and have observed this to be true.": 1, "If it's not apparent, they don't need to know. ": 1, 'If it would potentially affect my ability to do the job or might require special equipment/etc then it would only be fair and honest.': 1, "Wouldn't want to jeopardize my chances at the position": 1, 'no stigma, high probability of sympathy/understanding': 1, 'Depends on relevance to performance': 1, 'I would be worried it would be seen as a pity play or distraction from my qualifications.': 1, "Although illegal, I wouldn't want a p ...
# Column:  Would you bring up a mental health issue with a potential employer in an interview?
# {'No': 883, 'Maybe': 438, 'Yes': 112}
# Column:  Why or why not?.1
# {nan: 307, 'Stigma': 14, 'Stigma.': 9, 'Same as above': 7, 'See above': 4, 'stigma': 3, 'same as above': 3, 'Same as above.': 3, 'Same reason as above.': 3, 'Fear of not getting the job': 3, 'Fear of discrimination ': 2, 'Fear of discrimination': 2, 'Same reason as above': 2, 'Same as physical. ': 2, "I wouldn't get the job": 2, 'Same reason.': 2, 'never. you have no background info about the person who is interviewing you and their understanding of mental health.': 1, 'Again, it has nothing to do with the ability to perform my role. I am not my mental illness.': 1, "There is absolutely no way it could help, and a lot lot lot of ways it could hurt. And even though I should be protected by non-discrimination laws, if someone did use it in their decision-making, I'd have virtually no recourse.": 1, 'None of their business as long as I feel I can perform my work ': 1, "Disclosing mental illness up front is a good way to know an employer's stance or attitude towards mental illness and would help me decide if employment at that business would be worth it for me": 1, "There is still a stigma around mental health issues. The interviewer's perception of my skills and capability to perform the required tasks of the role may be altered because of this (even though I wouldn't have the job yet).": 1, 'It may affect how I work but the employer may not take it seriously depending on the illness': 1, 'Fear of discrimination.': 1, "For the same reason as above, but I don't know at all whether the employer views mental health the same as physical health.": 1, 'This again would negatively reflect on your potential, especially more so that a physical problem.': 1, "I don't have one": 1, "Again, if it affected my direct functioning I probably would. I'm quite reserved anyway, and unless it could affect my work directly, it's not my employer's business.": 1, 'I would bring it up if I felt it would impact my ability to do my job.': 1, "They don't need to know unless/until it affects my work.": 1, 'fear': 1, "I wouldn't think it relevant to the interview.": 1, "Although illegal, I wouldn't want a mental health issue to weigh on someones mind when they make the decision whether or not to hire me.": 1, 'Na': 1, 'Concerned would not get the job': 1, "I need to know they understand. I don't want to work for someone who doesn't understand.": 1, "Uncertain about reception.  Very difficult to determine an interviewer's experience and perception of mental illness.": 1, "People have so much stigma and I don't want to find out what kind, I want to get hired": 1, 'I deal with bouts of Anxiety and Depression but not clinical levels. Sometimes it gets the better of me but it has never been obstructive': 1, 'Do not want to be discriminated against': 1, "This seems like it would be disqualifying myself or bringing up trouble that my employer likely wouldn't want to deal with. ": 1, 'to get support': 1, 'Mental health stigmas mean that I feel uncomfortable discussing mental issues up front': 1, 'It is what it is. If that causes a problem, I should not work there.': 1, 'I would be worried that it would hinder my chances as a potential candidate': 1, 'They would immediately give the "short interview" and show you the door. That\'s career suicide. What if someone said "I\'m manic depressive, sometimes I can\'t get shit done because I\'m too depressed. Other times I\'ll get more done in 4 hours than your entire team will in a week." Most companies are going to think you\'re nuts.': 1, 'I have several severe mental health issues that would greatly affect my work.': 1, 'There is still too much stigma attached to mental health and the possibility for discrimination is too high. I might disclose it *after* being hired and passing any probationary period. ': 1, 'Potential negative impact on job.': 1, "I don't think they would hire me, in the first place.": 1, 'Depends on wether I feel comfortable enough during the interview or when they bring it up in a non-threatening way. ...
# Column:  Do you feel that being identified as a person with a mental health issue would hurt your career?
# {'Maybe': 588, 'Yes, I think it would': 563, "No, I don't think it would": 147, 'Yes, it has': 105, 'No, it has not': 30}
# Column:  Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?
# {'Maybe': 591, 'Yes, I think they would': 403, "No, I don't think they would": 348, 'No, they do not': 49, 'Yes, they do': 42}
# Column:  How willing would you be to share with friends and family that you have a mental illness?
# {'Somewhat open': 640, 'Very open': 251, 'Somewhat not open': 214, 'Neutral': 141, 'Not applicable to me (I do not have a mental illness)': 112, 'Not open at all': 75}
# Column:  Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?
# {'No': 567, 'Maybe/Not sure': 346, 'Yes, I observed': 264, 'Yes, I experienced': 167, nan: 89}
# Column:  Have your observations of how another individual who discussed a mental health disorder made you less likely to reveal a mental health issue yourself in your current workplace?
# {nan: 776, 'Yes': 246, 'No': 234, 'Maybe': 177}
# Column:  Do you have a family history of mental illness?
# {'Yes': 670, 'No': 488, "I don't know": 275}
# Column:  Have you had a mental health disorder in the past?
# {'Yes': 736, 'No': 451, 'Maybe': 246}
# Column:  Do you currently have a mental health disorder?
# {'Yes': 575, 'No': 531, 'Maybe': 327}
# Column:  If yes, what condition(s) have you been diagnosed with?
# {nan: 865, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)': 117, 'Mood Disorder (Depression, Bipolar Disorder, etc)': 102, 'Anxiety Disorder (Generalized, Social, Phobia, etc)': 47, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder': 26, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder': 22, 'Attention Deficit Hyperactivity Disorder': 18, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Attention Deficit Hyperactivity Disorder': 12, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Post-traumatic Stress Disorder': 11, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Eating Disorder (Anorexia, Bulimia, etc)': 10, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Obsessive-Compulsive Disorder': 9, 'Post-traumatic Stress Disorder': 7, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Stress Response Syndromes': 6, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Substance Use Disorder|Addictive Disorder': 6, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Anxiety Disorder (Generalized, Social, Phobia, etc)': 6, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Obsessive-Compulsive Disorder': 5, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Substance Use Disorder': 5, 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)': 5, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 4, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Post-traumatic Stress Disorder': 4, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Addictive Disorder': 4, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Stress Response Syndromes': 4, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Post-traumatic Stress Disorder': 4, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Dissociative Disorder': 3, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Eating Disorder (Anorexia, Bulimia, etc)|Obsessive-Compulsive Disorder': 3, 'Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 3, 'Obsessive-Compulsive Disorder': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Obsessive-Compulsive Disorder': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Post-traumatic Stress Disorder': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)|Stress Response Syndromes': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Post-traumatic Stress Disorder': 2, 'Attention Deficit Hyperactivity Disorder|Mood Disorder (Depression, Bipolar Disorder, etc)': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Post-traumatic Stress Disorder|Stress Response Syndromes': 2, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Stress Response Syndromes': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Post-traumatic Stress Disorder|Substance Use Disorder|Addictive ...
# Column:  If maybe, what condition(s) do you believe you have?
# {nan: 1111, 'Mood Disorder (Depression, Bipolar Disorder, etc)': 55, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)': 49, 'Anxiety Disorder (Generalized, Social, Phobia, etc)': 35, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder': 10, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder': 10, 'Attention Deficit Hyperactivity Disorder': 7, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Stress Response Syndromes': 7, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Post-traumatic Stress Disorder': 7, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 6, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Obsessive-Compulsive Disorder': 4, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 4, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Stress Response Syndromes': 4, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 4, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Attention Deficit Hyperactivity Disorder': 4, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Anxiety Disorder (Generalized, Social, Phobia, etc)': 4, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Obsessive-Compulsive Disorder': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Obsessive-Compulsive Disorder|Stress Response Syndromes': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Post-traumatic Stress Disorder|Stress Response Syndromes': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Addictive Disorder': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Obsessive-Compulsive Disorder': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Post-traumatic Stress Disorder': 3, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Eating Disorder (Anorexia, Bulimia, etc)': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Addictive Disorder': 3, 'Substance Use Disorder': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Stress Response Syndromes': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 2, 'Stress Response Syndromes': 2, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)|Obsessive-Compulsive Disorder|Substance Use Disorder': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Eating Disorder (Anorexia, Bulimia, etc)': 2, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Obsessive-Compulsive Disorder': 2, 'Personality Disorder (Borderline, Antisocial, Paranoid, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Anxiety Disorder (Generalized, Social, Phobia, etc)': 2, 'Eating Disorder (Anorexia, Bulimia, etc)': 2, 'Post-traumatic Stress Disorder': 2, 'Substance Use Disorder|Addictive Disorder': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)|Stress Response Syndromes': 2, 'Anxiety Disorder (Generalized ...
# Column:  Have you been diagnosed with a mental health condition by a medical professional?
# {'No': 717, 'Yes': 716}
# Column:  If so, what condition(s) were you diagnosed with?
# {nan: 722, 'Mood Disorder (Depression, Bipolar Disorder, etc)': 187, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)': 150, 'Anxiety Disorder (Generalized, Social, Phobia, etc)': 64, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder': 33, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder': 29, 'Attention Deficit Hyperactivity Disorder': 25, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Attention Deficit Hyperactivity Disorder': 17, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Obsessive-Compulsive Disorder': 13, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Post-traumatic Stress Disorder': 13, 'Post-traumatic Stress Disorder': 9, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Anxiety Disorder (Generalized, Social, Phobia, etc)': 7, 'Stress Response Syndromes': 6, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Stress Response Syndromes': 6, 'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)': 6, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Post-traumatic Stress Disorder': 6, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Stress Response Syndromes': 6, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Obsessive-Compulsive Disorder': 5, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Eating Disorder (Anorexia, Bulimia, etc)': 4, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Post-traumatic Stress Disorder': 4, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Post-traumatic Stress Disorder': 4, 'Obsessive-Compulsive Disorder': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Substance Use Disorder|Addictive Disorder': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 3, 'Depression': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Stress Response Syndromes': 3, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)|Stress Response Syndromes': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Obsessive-Compulsive Disorder|Post-traumatic Stress Disorder': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Post-traumatic Stress Disorder|Stress Response Syndromes': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)|Post-traumatic Stress Disorder': 2, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder|Post-traumatic Stress Disorder': 2, 'Mood Disorder (Depression, Bipolar Disorder, etc)|Substance Use Disorder': 2, 'Substance Use Disorder': 2, 'Attention Deficit Hyperactivity Disorder|Mood Disorder (Depression, Bipolar Disorder, etc)': 2, 'Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Dissociative Disorder': 2, 'Gender Identity Disorder': 1, 'Addictive Disorder|Substance Use Disorder|Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Personality Disorder (Border ...
# Column:  Have you ever sought treatment for a mental health issue from a mental health professional?
# {1: 839, 0: 594}
# Column:  If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?
# {'Not applicable to me': 557, 'Sometimes': 369, 'Rarely': 322, 'Never': 120, 'Often': 65}
# Column:  If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?
# {'Often': 538, 'Not applicable to me': 468, 'Sometimes': 363, 'Rarely': 52, 'Never': 12}
# Column:  What is your age?
# {30: 94, 31: 82, 29: 79, 35: 74, 28: 74, 32: 72, 34: 69, 33: 69, 26: 64, 27: 63, 37: 59, 39: 55, 38: 54, 36: 50, 25: 44, 24: 42, 40: 36, 22: 32, 44: 31, 43: 30, 42: 29, 45: 27, 23: 24, 41: 24, 46: 22, 21: 15, 47: 14, 49: 13, 55: 12, 48: 9, 50: 9, 51: 7, 52: 7, 54: 7, 20: 6, 56: 5, 19: 4, 57: 4, 63: 4, 53: 3, 59: 2, 61: 2, 99: 1, 74: 1, 65: 1, 70: 1, 66: 1, 3: 1, 62: 1, 58: 1, 15: 1, 17: 1, 323: 1}
# Column:  What is your gender?
# {'Male': 610, 'male': 249, 'Female': 153, 'female': 95, 'M': 86, 'm': 79, 'F': 38, 'f': 23, 'Male ': 11, 'Female ': 9, 'non-binary': 4, 'woman': 4, 'female ': 3, 'man': 3, 'Woman': 3, nan: 3, 'Man': 2, 'Agender': 2, 'Nonbinary': 2, 'Male (cis)': 2, 'male ': 2, 'M|': 1, 'female/woman': 1, 'Genderfluid': 1, 'Other/Transfeminine': 1, 'Androgynous': 1, 'Genderqueer': 1, 'Genderfluid (born female)': 1, 'Dude': 1, 'Queer': 1, 'AFAB': 1, 'Cisgender Female': 1, 'Unicorn': 1, 'Male.': 1, 'fem': 1, 'cisdude': 1, 'genderqueer woman': 1, 'female-bodied; no feelings about gender': 1, 'Malr': 1, 'Sex is male': 1, 'human': 1, 'MALE': 1, 'mtf': 1, 'nb masculine': 1, 'cis male': 1, 'Cis female ': 1, "I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? ": 1, 'Transitioned, M2F': 1, 'Male (trans, FtM)': 1, 'Female (props for making this a freeform field, though)': 1, 'genderqueer': 1, 'Transgender woman': 1, 'Human': 1, 'Bigender': 1, 'Fluid': 1, 'male 9:1 female, roughly': 1, ' Female': 1, 'Other': 1, 'Genderflux demi-girl': 1, 'Female assigned at birth ': 1, 'I identify as female.': 1, 'Cis-woman': 1, 'Cis male': 1, 'none of your business': 1, 'fm': 1, 'Enby': 1, 'mail': 1, 'Cis Male': 1, 'Male/genderqueer': 1, 'Female or Multi-Gender Femme': 1, 'cis man': 1}
# Column:  What country do you live in?
# {'United States of America': 840, 'United Kingdom': 180, 'Canada': 78, 'Germany': 58, 'Netherlands': 48, 'Australia': 35, 'Sweden': 19, 'France': 16, 'Ireland': 15, 'Switzerland': 10, 'Brazil': 10, 'India': 9, 'Russia': 9, 'New Zealand': 9, 'Denmark': 7, 'Finland': 7, 'Bulgaria': 7, 'Belgium': 5, 'Italy': 5, 'Poland': 4, 'Romania': 4, 'Spain': 4, 'Austria': 4, 'South Africa': 4, 'Czech Republic': 3, 'Chile': 3, 'Norway': 3, 'Pakistan': 3, 'Mexico': 2, 'Afghanistan': 2, 'Israel': 2, 'Colombia': 2, 'Estonia': 2, 'Bosnia and Herzegovina': 2, 'Japan': 2, 'Lithuania': 2, 'Other': 2, 'Venezuela': 1, 'Argentina': 1, 'Guatemala': 1, 'Brunei': 1, 'Greece': 1, 'Serbia': 1, 'Bangladesh': 1, 'Costa Rica': 1, 'Hungary': 1, 'Vietnam': 1, 'Iran': 1, 'Taiwan': 1, 'Algeria': 1, 'China': 1, 'Slovakia': 1, 'Ecuador': 1}
# Column:  What US state or territory do you live in?
# {nan: 593, 'California': 130, 'Illinois': 56, 'Michigan': 48, 'New York': 45, 'Texas': 43, 'Washington': 43, 'Minnesota': 42, 'Oregon': 37, 'Pennsylvania': 33, 'Colorado': 28, 'Tennessee': 27, 'Ohio': 25, 'Indiana': 25, 'Massachusetts': 23, 'North Carolina': 21, 'Florida': 21, 'Maryland': 16, 'Virginia': 15, 'Georgia': 14, 'Kansas': 14, 'Oklahoma': 13, 'Wisconsin': 13, 'Missouri': 12, 'Nebraska': 12, 'New Jersey': 7, 'Utah': 6, 'New Hampshire': 5, 'Arizona': 5, 'Connecticut': 5, 'Iowa': 5, 'Maine': 5, 'Vermont': 5, 'North Dakota': 4, 'Kentucky': 4, 'South Dakota': 4, 'New Mexico': 4, 'Alabama': 4, 'District of Columbia': 3, 'Nevada': 3, 'Idaho': 3, 'Rhode Island': 3, 'Louisiana': 2, 'Alaska': 2, 'West Virginia': 2, 'Montana': 1, 'South Carolina': 1, 'Delaware': 1}
# Column:  What country do you work in?
# {'United States of America': 851, 'United Kingdom': 183, 'Canada': 74, 'Germany': 58, 'Netherlands': 47, 'Australia': 34, 'Sweden': 20, 'Ireland': 15, 'France': 14, 'Switzerland': 10, 'Brazil': 10, 'India': 9, 'New Zealand': 9, 'Russia': 9, 'Bulgaria': 7, 'Finland': 7, 'Denmark': 7, 'Belgium': 5, 'South Africa': 4, 'Austria': 4, 'Poland': 4, 'Italy': 3, 'Chile': 3, 'Czech Republic': 3, 'Romania': 3, 'Norway': 3, 'Spain': 3, 'Bosnia and Herzegovina': 2, 'Mexico': 2, 'Pakistan': 2, 'Estonia': 2, 'Other': 2, 'Afghanistan': 2, 'Israel': 2, 'Colombia': 2, 'Argentina': 1, 'Turkey': 1, 'Brunei': 1, 'Bangladesh': 1, 'Ecuador': 1, 'Vietnam': 1, 'Iran': 1, 'China': 1, 'Venezuela': 1, 'Lithuania': 1, 'Slovakia': 1, 'Hungary': 1, 'Japan': 1, 'Costa Rica': 1, 'Serbia': 1, 'Greece': 1, 'Guatemala': 1, 'United Arab Emirates': 1}
# Column:  What US state or territory do you work in?
# {nan: 582, 'California': 141, 'Illinois': 58, 'New York': 49, 'Michigan': 47, 'Texas': 44, 'Minnesota': 43, 'Washington': 42, 'Oregon': 34, 'Pennsylvania': 32, 'Colorado': 28, 'Tennessee': 28, 'Indiana': 25, 'Ohio': 25, 'Massachusetts': 25, 'North Carolina': 21, 'Florida': 19, 'Kansas': 14, 'Oklahoma': 14, 'Wisconsin': 14, 'Maryland': 14, 'Georgia': 14, 'Virginia': 13, 'Nebraska': 12, 'Missouri': 11, 'District of Columbia': 7, 'New Jersey': 7, 'Utah': 6, 'Arizona': 6, 'Connecticut': 5, 'Vermont': 5, 'Iowa': 5, 'New Mexico': 4, 'Maine': 4, 'Alabama': 4, 'North Dakota': 4, 'Kentucky': 4, 'South Dakota': 4, 'New Hampshire': 3, 'Nevada': 3, 'Rhode Island': 2, 'Alaska': 2, 'Louisiana': 2, 'Idaho': 2, 'Hawaii': 1, 'Delaware': 1, 'West Virginia': 1, 'South Carolina': 1, 'Montana': 1}
# Column:  Which of the following best describes your work position?
# {'Back-end Developer': 263, 'Front-end Developer': 125, 'Other': 112, 'Supervisor/Team Lead': 68, 'Back-end Developer|Front-end Developer': 61, 'DevOps/SysAdmin': 54, 'One-person shop': 50, 'Executive Leadership': 46, 'Front-end Developer|Back-end Developer': 40, 'Support': 34, 'Designer': 28, 'Dev Evangelist/Advocate': 28, 'Supervisor/Team Lead|Back-end Developer': 19, 'Front-end Developer|Designer': 18, 'DevOps/SysAdmin|Back-end Developer|Front-end Developer': 17, 'Back-end Developer|DevOps/SysAdmin': 16, 'DevOps/SysAdmin|Back-end Developer': 15, 'Supervisor/Team Lead|Back-end Developer|Front-end Developer': 15, 'Front-end Developer|Back-end Developer|DevOps/SysAdmin': 12, 'Supervisor/Team Lead|DevOps/SysAdmin|Back-end Developer': 9, 'Supervisor/Team Lead|DevOps/SysAdmin|Back-end Developer|Front-end Developer': 8, 'DevOps/SysAdmin|Support|Back-end Developer|Front-end Developer': 8, 'Back-end Developer|One-person shop': 7, 'DevOps/SysAdmin|Support': 6, 'Front-end Developer|Back-end Developer|DevOps/SysAdmin|Supervisor/Team Lead': 6, 'Support|Back-end Developer': 6, 'Supervisor/Team Lead|Front-end Developer': 6, 'Front-end Developer|Back-end Developer|Supervisor/Team Lead': 6, 'HR': 5, 'Other|Back-end Developer': 5, 'One-person shop|Front-end Developer|Back-end Developer': 5, 'DevOps/SysAdmin|Back-end Developer|Front-end Developer|Designer': 5, 'One-person shop|Back-end Developer': 5, 'Dev Evangelist/Advocate|Back-end Developer': 4, 'Support|Back-end Developer|Front-end Developer': 4, 'Supervisor/Team Lead|DevOps/SysAdmin': 4, 'Executive Leadership|Supervisor/Team Lead': 4, 'One-person shop|Back-end Developer|DevOps/SysAdmin': 4, 'Designer|Front-end Developer': 4, 'Back-end Developer|Front-end Developer|Designer': 4, 'Sales': 4, 'Back-end Developer|Supervisor/Team Lead': 4, 'DevOps/SysAdmin|Supervisor/Team Lead': 4, 'Front-end Developer|Back-end Developer|Support': 3, 'Other|Dev Evangelist/Advocate': 3, 'Support|Other': 3, 'Back-end Developer|Front-end Developer|One-person shop': 3, 'Dev Evangelist/Advocate|Back-end Developer|Front-end Developer': 3, 'DevOps/SysAdmin|Front-end Developer|Back-end Developer|Support': 3, 'Other|Supervisor/Team Lead': 3, 'Supervisor/Team Lead|Support': 3, 'One-person shop|Designer|Front-end Developer': 3, 'DevOps/SysAdmin|Support|Back-end Developer': 3, 'DevOps/SysAdmin|Back-end Developer|Front-end Developer|One-person shop': 3, 'One-person shop|Front-end Developer|Back-end Developer|DevOps/SysAdmin': 3, 'Support|Back-end Developer|Front-end Developer|One-person shop': 3, 'Supervisor/Team Lead|DevOps/SysAdmin|Support|Back-end Developer|Front-end Developer|Designer': 3, 'Dev Evangelist/Advocate|DevOps/SysAdmin|Back-end Developer': 3, 'Other|Dev Evangelist/Advocate|Support': 2, 'Designer|Front-end Developer|Back-end Developer|Supervisor/Team Lead': 2, 'Supervisor/Team Lead|Support|Back-end Developer': 2, 'Other|Support': 2, 'One-person shop|Other': 2, 'Other|Front-end Developer|Designer|One-person shop': 2, 'Back-end Developer|Dev Evangelist/Advocate|Supervisor/Team Lead': 2, 'Supervisor/Team Lead|Back-end Developer|One-person shop': 2, 'Front-end Developer|Back-end Developer|Dev Evangelist/Advocate': 2, 'Other|Back-end Developer|Front-end Developer|Designer': 2, 'Supervisor/Team Lead|DevOps/SysAdmin|Front-end Developer|Back-end Developer': 2, 'DevOps/SysAdmin|Dev Evangelist/Advocate|Supervisor/Team Lead|Executive Leadership': 2, 'Support|DevOps/SysAdmin': 2, 'Support|Back-end Developer|One-person shop': 2, 'Supervisor/Team Lead|Back-end Developer|DevOps/SysAdmin': 2, 'Front-end Developer|Back-end Developer|Executive Leadership': 2, 'One-person shop|Front-end Developer|Back-end Developer|DevOps/SysAdmin|Supervisor/Team Lead': 2, 'Support|Front-end Developer|Back-end Developer': 2, 'Supervisor/Team Lead|Back-end Developer|Front-end Developer|Designer': 2, 'Dev Evangelist/Advocate|DevOps/SysAdmin': 2, 'Supervisor/Team Lead|Front-end Developer|Back-end Developer': 2, 'Back-end Developer|DevOps/SysAdmin ...
# Column:  Do you work remotely?
# {'Sometimes': 757, 'Always': 343, 'Never': 333}

# %% [markdown]
# #

# %% [markdown]
# # Cleaning the Dataset

# %%
# copying df for the use
df = df_original.copy()

# %%
# ?maybe apply some keyword encoding
# custom generated new column names
generated_column_names = ["self_employed", "employee_number_range", "is_primary_company_tech", "is_primary_role_tech", "is_provided_mental_health_benefits", "is_known_mental_health_care", "has_formally_mental_health_discussed_by_current_emp", "is_mental_health_resource_offered_by_current_emp", "would_anonymity_be_protected_by_current_emp", "how_easy_to_ask_for_medical_leave", "would_discuss_mental_health_disorder_negative_consequences_with_current_emp", "would_discuss_physical_health_disorder_with_current_emp", "would_feel_comfortable_to_discuss_mental_health_with_current_coworker", "would_feel_comfortable_to_discuss_mental_health_with_current_supervisor", "would_mental_health_be_taken_seriously_by_emp", "would_observe_negative_consequences_in_current_coworkers", "has_medical_coverage", "know_local_or_online_resources_for_help", "reveal_disorder_if_diagnosed_or_treated_to_clients_or_business_contact", "affected_negatively_if_reveled_to_client_or_business_contact", "reveal_disorder_if_diagnosed_or_treated_to_coworker_or_employee", "affected_negatively_if_revealed_to_coworker_or_employee", "productivity_affected_by_mental_health", "percentage_of_worktime_affected_by_mental_health", "has_previous_employers", "provided_mental_health_benefits_by_previous_employer", "aware_of_options_provided_by_previous_employer", "has_formally_discussed_mental_health_with_previous_employer", "is_mental_health_resource_offered_by_previous_employer", "would_anonymity_protected_by_previous_employer", "would_discuss_mental_health_disorder_negative_consequences_with_previous_employer", "would_discuss_physical_health_disorder_negative_consequences_with_previous_employer", "would_feel_comfortable_to_discuss_mental_health_with_previous_coworker", "would_feel_comfortable_to_discuss_mental_health_with_previous_supervisor", "would_mental_health_be_taken_seriously_by_previous_employer", "would_observe_negative_consequences_in_previous_coworkers", "would_bring_up_physical_health_issue_in_interview", "physical_health_reason", "would_bring_up_mental_health_issue_in_interview", "mental_health_reason", "would_hurt_career_if_identified_with_mental_health_issue", "would_be_viewed_negatively_if_suffered_with_mental_health_issues", "willingness_to_share_mental_health_issues_with_friends_and_family", "have_seen_bad_response_to_mental_health_issue_now_or_before", "have_other_observations_affected_desire_to_reveal_mental_health_issue", "has_family_history_of_mental_illness", "had_a_mental_disorder_before", "have_a_mental_disorder_now", "if_yes_what_condition_diagnosed", "if_maybe_what_condition_you_believe_you_have", "diagnosed_by_a_medical_professional", "if_diagnosed_so_what_condition", "sought_treatment_from_professional", "would_interfere_with_work_when_treated_effectively", "would_interfere_with_work_when_not_treated_effectively", "age", "gender", "country_of_residence", "usa_state_if_you_live", "country_of_work", "usa_state_if_you_work", "work_position", "do_you_work_remotely"]

# replacing comlumn names
df.set_axis(generated_column_names, axis=1, inplace=True)

# %%
# printing dataframe without print() function happen to be more beautiful and easy to read
df.head()
# Out:
#    self_employed employee_number_range  is_primary_company_tech  \
# 0              0                26-100                      1.0
# 1              0                  6-25                      1.0
# 2              0                  6-25                      1.0
# 3              1                   NaN                      NaN
# 4              0                  6-25                      0.0
#
#    is_primary_role_tech is_provided_mental_health_benefits  \
# 0                   NaN    Not eligible for coverage / N/A
# 1                   NaN                                 No
# 2                   NaN                                 No
# 3                   NaN                                NaN
# 4                   1.0                                Yes
#
#   is_known_mental_health_care  \
# 0                         NaN
# 1                         Yes
# 2                         NaN
# 3                         NaN
# 4                         Yes
#
#   has_formally_mental_health_discussed_by_current_emp  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#   is_mental_health_resource_offered_by_current_emp  \
# 0                                               No
# 1                                              Yes
# 2                                               No
# 3                                              NaN
# 4                                               No
#
#   would_anonymity_be_protected_by_current_emp  \
# 0                                I don't know
# 1                                         Yes
# 2                                I don't know
# 3                                         NaN
# 4                                          No
#
#   how_easy_to_ask_for_medical_leave  \
# 0                         Very easy
# 1                     Somewhat easy
# 2        Neither easy nor difficult
# 3                               NaN
# 4        Neither easy nor difficult
#
#   would_discuss_mental_health_disorder_negative_consequences_with_current_emp  \
# 0                                                 No
# 1                                                 No
# 2                                              Maybe
# 3                                                NaN
# 4                                                Yes
#
#   would_discuss_physical_health_disorder_with_current_emp  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                              Maybe
#
#   would_feel_comfortable_to_discuss_mental_health_with_current_coworker  \
# 0                                              Maybe
# 1                                              Maybe
# 2                                              Maybe
# 3                                                NaN
# 4                                              Maybe
#
#   would_feel_comfortable_to_discuss_mental_health_with_current_supervisor  \
# 0                                                Yes
# 1                                                Yes
# 2                                              Maybe
# 3                                                NaN
# 4                                                 No
#
#   would_mental_health_be_taken_seriously_by_emp  \
# 0                                  I don't know
# 1                                           Yes
# 2                                  I don't know
# 3                                           NaN
# 4                                            No
#
#   would_observe_negative_consequences_in_current_coworkers  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#    has_medical_coverage know_local_or_online_resources_for_help  \
# 0                   NaN                                     NaN
# 1                   NaN                                     NaN
# 2                   NaN                                     NaN
# 3                   1.0                     Yes, I know several
# 4                   NaN                                     NaN
#
#   reveal_disorder_if_diagnosed_or_treated_to_clients_or_business_contact  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                          Sometimes, if it comes up
# 4                                                NaN
#
#   affected_negatively_if_reveled_to_client_or_business_contact  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                       I'm not sure
# 4                                                NaN
#
#   reveal_disorder_if_diagnosed_or_treated_to_coworker_or_employee  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                          Sometimes, if it comes up
# 4                                                NaN
#
#   affected_negatively_if_revealed_to_coworker_or_employee  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                       I'm not sure
# 4                                                NaN
#
#   productivity_affected_by_mental_health  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    Yes
# 4                                    NaN
#
#   percentage_of_worktime_affected_by_mental_health  has_previous_employers  \
# 0                                              NaN                       1
# 1                                              NaN                       1
# 2                                              NaN                       1
# 3                                            1-25%                       1
# 4                                              NaN                       1
#
#   provided_mental_health_benefits_by_previous_employer  \
# 0                                       No, none did
# 1                                  Yes, they all did
# 2                                       No, none did
# 3                                           Some did
# 4                                       I don't know
#
#   aware_of_options_provided_by_previous_employer  \
# 0                      N/A (not currently aware)
# 1                            I was aware of some
# 2                      N/A (not currently aware)
# 3                      N/A (not currently aware)
# 4                      N/A (not currently aware)
#
#   has_formally_discussed_mental_health_with_previous_employer  \
# 0                                       I don't know
# 1                                           None did
# 2                                           None did
# 3                                           None did
# 4                                           Some did
#
#   is_mental_health_resource_offered_by_previous_employer  \
# 0                                           None did
# 1                                           Some did
# 2                                           Some did
# 3                                           None did
# 4                                           None did
#
#   would_anonymity_protected_by_previous_employer  \
# 0                                   I don't know
# 1                                    Yes, always
# 2                                   I don't know
# 3                                   I don't know
# 4                                   I don't know
#
#   would_discuss_mental_health_disorder_negative_consequences_with_previous_employer  \
# 0                                       Some of them
# 1                                       None of them
# 2                                       I don't know
# 3                                       Some of them
# 4                                       Some of them
#
#   would_discuss_physical_health_disorder_negative_consequences_with_previous_employer  \
# 0                                       None of them
# 1                                       None of them
# 2                                       Some of them
# 3                                       Some of them
# 4                                       Some of them
#
#   would_feel_comfortable_to_discuss_mental_health_with_previous_coworker  \
# 0                      Some of my previous employers
# 1               No, at none of my previous employers
# 2                      Some of my previous employers
# 3                      Some of my previous employers
# 4               No, at none of my previous employers
#
#   would_feel_comfortable_to_discuss_mental_health_with_previous_supervisor  \
# 0                      Some of my previous employers
# 1                      Some of my previous employers
# 2                                       I don't know
# 3                      Some of my previous employers
# 4                      Some of my previous employers
#
#   would_mental_health_be_taken_seriously_by_previous_employer  \
# 0                                       I don't know
# 1                                           Some did
# 2                                       I don't know
# 3                                       I don't know
# 4                                           Some did
#
#   would_observe_negative_consequences_in_previous_coworkers  \
# 0                                       None of them
# 1                                       None of them
# 2                                       Some of them
# 3                                       Some of them
# 4                                       Some of them
#
#   would_bring_up_physical_health_issue_in_interview  \
# 0                                             Maybe
# 1                                             Maybe
# 2                                               Yes
# 3                                               Yes
# 4                                             Maybe
#
#                               physical_health_reason  \
# 0                                                NaN
# 1  It would depend on the health issue. If there ...
# 2  They would provable need to know, to Judge if ...
# 3  old back injury, doesn't cause me many issues ...
# 4  Depending on the interview stage and whether I...
#
#   would_bring_up_mental_health_issue_in_interview  \
# 0                                           Maybe
# 1                                              No
# 2                                             Yes
# 3                                           Maybe
# 4                                              No
#
#                                 mental_health_reason  \
# 0                                                NaN
# 1  While mental health has become a more prominen...
# 2                                   Stigma, mainly.
# 3  would not if I was not 100% sure that the disc...
# 4                                       I don't know
#
#   would_hurt_career_if_identified_with_mental_health_issue  \
# 0                                              Maybe
# 1                         No, I don't think it would
# 2                                              Maybe
# 3                              Yes, I think it would
# 4                              Yes, I think it would
#
#   would_be_viewed_negatively_if_suffered_with_mental_health_issues  \
# 0                       No, I don't think they would
# 1                       No, I don't think they would
# 2                                              Maybe
# 3                                              Maybe
# 4                                              Maybe
#
#   willingness_to_share_mental_health_issues_with_friends_and_family  \
# 0                                      Somewhat open
# 1                                      Somewhat open
# 2                                      Somewhat open
# 3                                            Neutral
# 4                                      Somewhat open
#
#   have_seen_bad_response_to_mental_health_issue_now_or_before  \
# 0                                                 No
# 1                                                 No
# 2                                     Maybe/Not sure
# 3                                                 No
# 4                                 Yes, I experienced
#
#   have_other_observations_affected_desire_to_reveal_mental_health_issue  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                NaN
# 4                                                Yes
#
#   has_family_history_of_mental_illness had_a_mental_disorder_before  \
# 0                                   No                          Yes
# 1                                  Yes                          Yes
# 2                                   No                        Maybe
# 3                                   No                          Yes
# 4                                  Yes                          Yes
#
#   have_a_mental_disorder_now  \
# 0                         No
# 1                        Yes
# 2                         No
# 3                        Yes
# 4                        Yes
#
#                      if_yes_what_condition_diagnosed  \
# 0                                                NaN
# 1  Anxiety Disorder (Generalized, Social, Phobia,...
# 2                                                NaN
# 3  Anxiety Disorder (Generalized, Social, Phobia,...
# 4  Anxiety Disorder (Generalized, Social, Phobia,...
#
#   if_maybe_what_condition_you_believe_you_have  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   diagnosed_by_a_medical_professional  \
# 0                                 Yes
# 1                                 Yes
# 2                                  No
# 3                                 Yes
# 4                                 Yes
#
#                       if_diagnosed_so_what_condition  \
# 0  Anxiety Disorder (Generalized, Social, Phobia,...
# 1  Anxiety Disorder (Generalized, Social, Phobia,...
# 2                                                NaN
# 3  Anxiety Disorder (Generalized, Social, Phobia,...
# 4  Anxiety Disorder (Generalized, Social, Phobia,...
#
#    sought_treatment_from_professional  \
# 0                                   0
# 1                                   1
# 2                                   1
# 3                                   1
# 4                                   1
#
#   would_interfere_with_work_when_treated_effectively  \
# 0                               Not applicable to me
# 1                                             Rarely
# 2                               Not applicable to me
# 3                                          Sometimes
# 4                                          Sometimes
#
#   would_interfere_with_work_when_not_treated_effectively  age  gender  \
# 0                               Not applicable to me       39    Male
# 1                                          Sometimes       29    male
# 2                               Not applicable to me       38   Male
# 3                                          Sometimes       43    male
# 4                                          Sometimes       43  Female
#
#        country_of_residence usa_state_if_you_live           country_of_work  \
# 0            United Kingdom                   NaN            United Kingdom
# 1  United States of America              Illinois  United States of America
# 2            United Kingdom                   NaN            United Kingdom
# 3            United Kingdom                   NaN            United Kingdom
# 4  United States of America              Illinois  United States of America
#
#   usa_state_if_you_work                                      work_position  \
# 0                   NaN                                 Back-end Developer
# 1              Illinois             Back-end Developer|Front-end Developer
# 2                   NaN                                 Back-end Developer
# 3                   NaN                               Supervisor/Team Lead
# 4              Illinois  Executive Leadership|Supervisor/Team Lead|Dev ...
#
#   do_you_work_remotely
# 0            Sometimes
# 1                Never
# 2               Always
# 3            Sometimes
# 4            Sometimes

# %% [markdown]
# ## Ordering Columns by the Number of Missing Data Points

# %%
columns_mapped_to_amount_of_NaN = dict(df.isna().sum())

# check which columns have missing data
for k, v in sorted(columns_mapped_to_amount_of_NaN.items(), key=lambda x: x[1], reverse=True):
    print(f"{k.replace('_', ' ')}"," "*(83-len(k)), f"{v}")
# Out:
# affected negatively if reveled to client or business contact                         1289
# percentage of worktime affected by mental health                                     1229
# is primary role tech                                                                 1170
# has medical coverage                                                                 1146
# know local or online resources for help                                              1146
# reveal disorder if diagnosed or treated to clients or business contact               1146
# reveal disorder if diagnosed or treated to coworker or employee                      1146
# affected negatively if revealed to coworker or employee                              1146
# productivity affected by mental health                                               1146
# if maybe what condition you believe you have                                         1111
# if yes what condition diagnosed                                                      865
# have other observations affected desire to reveal mental health issue                776
# if diagnosed so what condition                                                       722
# usa state if you live                                                                593
# usa state if you work                                                                582
# is known mental health care                                                          420
# physical health reason                                                               338
# mental health reason                                                                 307
# employee number range                                                                287
# is primary company tech                                                              287
# is provided mental health benefits                                                   287
# has formally mental health discussed by current emp                                  287
# is mental health resource offered by current emp                                     287
# would anonymity be protected by current emp                                          287
# how easy to ask for medical leave                                                    287
# would discuss mental health disorder negative consequences with current emp          287
# would discuss physical health disorder with current emp                              287
# would feel comfortable to discuss mental health with current coworker                287
# would feel comfortable to discuss mental health with current supervisor              287
# would mental health be taken seriously by emp                                        287
# would observe negative consequences in current coworkers                             287
# provided mental health benefits by previous employer                                 169
# aware of options provided by previous employer                                       169
# has formally discussed mental health with previous employer                          169
# is mental health resource offered by previous employer                               169
# would anonymity protected by previous employer                                       169
# would discuss mental health disorder negative consequences with previous employer    169
# would discuss physical health disorder negative consequences with previous employer  169
# would feel comfortable to discuss mental health with previous coworker               169
# would feel comfortable to discuss mental health with previous supervisor             169
# would mental health be taken seriously by previous employer                          169
# would observe negative consequences in previous coworkers                            169
# have seen bad response to mental health issue now or before                          89
# gender                                                                               3
# self employed                                                                        0
# has previous employers                                                               0
# would bring up physical health issue in interview                                    0
# would bring up mental health issue in interview                                      0
# would hurt career if identified with mental health issue                             0
# would be viewed negatively if suffered with mental health issues                     0
# willingness to share mental health issues with friends and family                    0
# has family history of mental illness                                                 0
# had a mental disorder before                                                         0
# have a mental disorder now                                                           0
# diagnosed by a medical professional                                                  0
# sought treatment from professional                                                   0
# would interfere with work when treated effectively                                   0
# would interfere with work when not treated effectively                               0
# age                                                                                  0
# country of residence                                                                 0
# country of work                                                                      0
# work position                                                                        0
# do you work remotely                                                                 0

# %% [markdown]
# ## Detecting Noisy/Dirty/Unnecessary Columns

# %%
# storing columns as keys and proportion of NaN as values
columns_mapped_to_proportion_of_NaN = {}

# map columns to proportion of missing data points
for k, v in columns_mapped_to_amount_of_NaN.items():
    perc_of_nans = v / df.shape[0]
    columns_mapped_to_proportion_of_NaN[k] = perc_of_nans

# %%
# visualizing the proportion of NaNs in decreasing order for each column
for k, v in sorted(columns_mapped_to_proportion_of_NaN.items(), key=lambda x: x[1], reverse=True):
    print(f"{k.replace('_', ' ')}"," "*(83-len(k)), f"{round(v, 3)}")
# Out:
# affected negatively if reveled to client or business contact                         0.9
# percentage of worktime affected by mental health                                     0.858
# is primary role tech                                                                 0.816
# has medical coverage                                                                 0.8
# know local or online resources for help                                              0.8
# reveal disorder if diagnosed or treated to clients or business contact               0.8
# reveal disorder if diagnosed or treated to coworker or employee                      0.8
# affected negatively if revealed to coworker or employee                              0.8
# productivity affected by mental health                                               0.8
# if maybe what condition you believe you have                                         0.775
# if yes what condition diagnosed                                                      0.604
# have other observations affected desire to reveal mental health issue                0.542
# if diagnosed so what condition                                                       0.504
# usa state if you live                                                                0.414
# usa state if you work                                                                0.406
# is known mental health care                                                          0.293
# physical health reason                                                               0.236
# mental health reason                                                                 0.214
# employee number range                                                                0.2
# is primary company tech                                                              0.2
# is provided mental health benefits                                                   0.2
# has formally mental health discussed by current emp                                  0.2
# is mental health resource offered by current emp                                     0.2
# would anonymity be protected by current emp                                          0.2
# how easy to ask for medical leave                                                    0.2
# would discuss mental health disorder negative consequences with current emp          0.2
# would discuss physical health disorder with current emp                              0.2
# would feel comfortable to discuss mental health with current coworker                0.2
# would feel comfortable to discuss mental health with current supervisor              0.2
# would mental health be taken seriously by emp                                        0.2
# would observe negative consequences in current coworkers                             0.2
# provided mental health benefits by previous employer                                 0.118
# aware of options provided by previous employer                                       0.118
# has formally discussed mental health with previous employer                          0.118
# is mental health resource offered by previous employer                               0.118
# would anonymity protected by previous employer                                       0.118
# would discuss mental health disorder negative consequences with previous employer    0.118
# would discuss physical health disorder negative consequences with previous employer  0.118
# would feel comfortable to discuss mental health with previous coworker               0.118
# would feel comfortable to discuss mental health with previous supervisor             0.118
# would mental health be taken seriously by previous employer                          0.118
# would observe negative consequences in previous coworkers                            0.118
# have seen bad response to mental health issue now or before                          0.062
# gender                                                                               0.002
# self employed                                                                        0.0
# has previous employers                                                               0.0
# would bring up physical health issue in interview                                    0.0
# would bring up mental health issue in interview                                      0.0
# would hurt career if identified with mental health issue                             0.0
# would be viewed negatively if suffered with mental health issues                     0.0
# willingness to share mental health issues with friends and family                    0.0
# has family history of mental illness                                                 0.0
# had a mental disorder before                                                         0.0
# have a mental disorder now                                                           0.0
# diagnosed by a medical professional                                                  0.0
# sought treatment from professional                                                   0.0
# would interfere with work when treated effectively                                   0.0
# would interfere with work when not treated effectively                               0.0
# age                                                                                  0.0
# country of residence                                                                 0.0
# country of work                                                                      0.0
# work position                                                                        0.0
# do you work remotely                                                                 0.0

# %%
data = {k:v for k, v in sorted(columns_mapped_to_proportion_of_NaN.items(), key=lambda x: x[1], reverse=True)}
plt.bar(data.keys(), height=data.values())
# Out:
# <BarContainer object of 63 artists>

# %% [markdown]
# ## Dropping Noisy/Dirty/Unnecessary

# %%
THRESHOLD = 0.5

# %%
# dropping columns where proportion of the missing data points is more than half of observations
for k, v in columns_mapped_to_proportion_of_NaN.items():
    if v >= THRESHOLD:
        df = df.drop(k, axis=1)

# %%
# number of dropped columns
print("Dropped Columns Number: %d" % (len(df_original.columns) - len(df.columns)))

# viewing dataframe after modification
df.head()
# Out:
# Dropped Columns Number: 13
#    self_employed employee_number_range  is_primary_company_tech  \
# 0              0                26-100                      1.0
# 1              0                  6-25                      1.0
# 2              0                  6-25                      1.0
# 3              1                   NaN                      NaN
# 4              0                  6-25                      0.0
#
#   is_provided_mental_health_benefits is_known_mental_health_care  \
# 0    Not eligible for coverage / N/A                         NaN
# 1                                 No                         Yes
# 2                                 No                         NaN
# 3                                NaN                         NaN
# 4                                Yes                         Yes
#
#   has_formally_mental_health_discussed_by_current_emp  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#   is_mental_health_resource_offered_by_current_emp  \
# 0                                               No
# 1                                              Yes
# 2                                               No
# 3                                              NaN
# 4                                               No
#
#   would_anonymity_be_protected_by_current_emp  \
# 0                                I don't know
# 1                                         Yes
# 2                                I don't know
# 3                                         NaN
# 4                                          No
#
#   how_easy_to_ask_for_medical_leave  \
# 0                         Very easy
# 1                     Somewhat easy
# 2        Neither easy nor difficult
# 3                               NaN
# 4        Neither easy nor difficult
#
#   would_discuss_mental_health_disorder_negative_consequences_with_current_emp  \
# 0                                                 No
# 1                                                 No
# 2                                              Maybe
# 3                                                NaN
# 4                                                Yes
#
#   would_discuss_physical_health_disorder_with_current_emp  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                              Maybe
#
#   would_feel_comfortable_to_discuss_mental_health_with_current_coworker  \
# 0                                              Maybe
# 1                                              Maybe
# 2                                              Maybe
# 3                                                NaN
# 4                                              Maybe
#
#   would_feel_comfortable_to_discuss_mental_health_with_current_supervisor  \
# 0                                                Yes
# 1                                                Yes
# 2                                              Maybe
# 3                                                NaN
# 4                                                 No
#
#   would_mental_health_be_taken_seriously_by_emp  \
# 0                                  I don't know
# 1                                           Yes
# 2                                  I don't know
# 3                                           NaN
# 4                                            No
#
#   would_observe_negative_consequences_in_current_coworkers  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                NaN
# 4                                                 No
#
#    has_previous_employers  \
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
#
#   provided_mental_health_benefits_by_previous_employer  \
# 0                                       No, none did
# 1                                  Yes, they all did
# 2                                       No, none did
# 3                                           Some did
# 4                                       I don't know
#
#   aware_of_options_provided_by_previous_employer  \
# 0                      N/A (not currently aware)
# 1                            I was aware of some
# 2                      N/A (not currently aware)
# 3                      N/A (not currently aware)
# 4                      N/A (not currently aware)
#
#   has_formally_discussed_mental_health_with_previous_employer  \
# 0                                       I don't know
# 1                                           None did
# 2                                           None did
# 3                                           None did
# 4                                           Some did
#
#   is_mental_health_resource_offered_by_previous_employer  \
# 0                                           None did
# 1                                           Some did
# 2                                           Some did
# 3                                           None did
# 4                                           None did
#
#   would_anonymity_protected_by_previous_employer  \
# 0                                   I don't know
# 1                                    Yes, always
# 2                                   I don't know
# 3                                   I don't know
# 4                                   I don't know
#
#   would_discuss_mental_health_disorder_negative_consequences_with_previous_employer  \
# 0                                       Some of them
# 1                                       None of them
# 2                                       I don't know
# 3                                       Some of them
# 4                                       Some of them
#
#   would_discuss_physical_health_disorder_negative_consequences_with_previous_employer  \
# 0                                       None of them
# 1                                       None of them
# 2                                       Some of them
# 3                                       Some of them
# 4                                       Some of them
#
#   would_feel_comfortable_to_discuss_mental_health_with_previous_coworker  \
# 0                      Some of my previous employers
# 1               No, at none of my previous employers
# 2                      Some of my previous employers
# 3                      Some of my previous employers
# 4               No, at none of my previous employers
#
#   would_feel_comfortable_to_discuss_mental_health_with_previous_supervisor  \
# 0                      Some of my previous employers
# 1                      Some of my previous employers
# 2                                       I don't know
# 3                      Some of my previous employers
# 4                      Some of my previous employers
#
#   would_mental_health_be_taken_seriously_by_previous_employer  \
# 0                                       I don't know
# 1                                           Some did
# 2                                       I don't know
# 3                                       I don't know
# 4                                           Some did
#
#   would_observe_negative_consequences_in_previous_coworkers  \
# 0                                       None of them
# 1                                       None of them
# 2                                       Some of them
# 3                                       Some of them
# 4                                       Some of them
#
#   would_bring_up_physical_health_issue_in_interview  \
# 0                                             Maybe
# 1                                             Maybe
# 2                                               Yes
# 3                                               Yes
# 4                                             Maybe
#
#                               physical_health_reason  \
# 0                                                NaN
# 1  It would depend on the health issue. If there ...
# 2  They would provable need to know, to Judge if ...
# 3  old back injury, doesn't cause me many issues ...
# 4  Depending on the interview stage and whether I...
#
#   would_bring_up_mental_health_issue_in_interview  \
# 0                                           Maybe
# 1                                              No
# 2                                             Yes
# 3                                           Maybe
# 4                                              No
#
#                                 mental_health_reason  \
# 0                                                NaN
# 1  While mental health has become a more prominen...
# 2                                   Stigma, mainly.
# 3  would not if I was not 100% sure that the disc...
# 4                                       I don't know
#
#   would_hurt_career_if_identified_with_mental_health_issue  \
# 0                                              Maybe
# 1                         No, I don't think it would
# 2                                              Maybe
# 3                              Yes, I think it would
# 4                              Yes, I think it would
#
#   would_be_viewed_negatively_if_suffered_with_mental_health_issues  \
# 0                       No, I don't think they would
# 1                       No, I don't think they would
# 2                                              Maybe
# 3                                              Maybe
# 4                                              Maybe
#
#   willingness_to_share_mental_health_issues_with_friends_and_family  \
# 0                                      Somewhat open
# 1                                      Somewhat open
# 2                                      Somewhat open
# 3                                            Neutral
# 4                                      Somewhat open
#
#   have_seen_bad_response_to_mental_health_issue_now_or_before  \
# 0                                                 No
# 1                                                 No
# 2                                     Maybe/Not sure
# 3                                                 No
# 4                                 Yes, I experienced
#
#   has_family_history_of_mental_illness had_a_mental_disorder_before  \
# 0                                   No                          Yes
# 1                                  Yes                          Yes
# 2                                   No                        Maybe
# 3                                   No                          Yes
# 4                                  Yes                          Yes
#
#   have_a_mental_disorder_now diagnosed_by_a_medical_professional  \
# 0                         No                                 Yes
# 1                        Yes                                 Yes
# 2                         No                                  No
# 3                        Yes                                 Yes
# 4                        Yes                                 Yes
#
#    sought_treatment_from_professional  \
# 0                                   0
# 1                                   1
# 2                                   1
# 3                                   1
# 4                                   1
#
#   would_interfere_with_work_when_treated_effectively  \
# 0                               Not applicable to me
# 1                                             Rarely
# 2                               Not applicable to me
# 3                                          Sometimes
# 4                                          Sometimes
#
#   would_interfere_with_work_when_not_treated_effectively  age  gender  \
# 0                               Not applicable to me       39    Male
# 1                                          Sometimes       29    male
# 2                               Not applicable to me       38   Male
# 3                                          Sometimes       43    male
# 4                                          Sometimes       43  Female
#
#        country_of_residence usa_state_if_you_live           country_of_work  \
# 0            United Kingdom                   NaN            United Kingdom
# 1  United States of America              Illinois  United States of America
# 2            United Kingdom                   NaN            United Kingdom
# 3            United Kingdom                   NaN            United Kingdom
# 4  United States of America              Illinois  United States of America
#
#   usa_state_if_you_work                                      work_position  \
# 0                   NaN                                 Back-end Developer
# 1              Illinois             Back-end Developer|Front-end Developer
# 2                   NaN                                 Back-end Developer
# 3                   NaN                               Supervisor/Team Lead
# 4              Illinois  Executive Leadership|Supervisor/Team Lead|Dev ...
#
#   do_you_work_remotely
# 0            Sometimes
# 1                Never
# 2               Always
# 3            Sometimes
# 4            Sometimes

# %% [markdown]
# ## Encoding

# %%
"""
    self_employed: already binary type
    
    {
        
    }
"""

# %%
"""
    employee_number_range: label encode the categories into:
    
    {
        '1-5': 0, 
        '6-25': 1, 
        '26-100': 2, 
        '100-500': 3, 
        '500-1000': 4, 
        'More than 1000': 5
    }
"""

# %%
"""
    is_primary_company_tech: assign most frequent value
"""

# %%
"""
    is_primary_role_tech: assign most frequent value
"""

# %%
"""
    is_provided_mental_health_benefits: assign floats to categories as below
    
    {
        'Yes': 1, 
        'I don't know: 0.5, 
        'Not eligible for coverage': 0.25, 
        'No': 0, 
    }
    
    NOTE: Given the fact that the answers listed here are not random but seem to come from a questionnaire, 
    we have decided to distinguish between the answers "No" and "Not eligible for coverage", 
    instead of combining them into one category (i.e. with value 0).
"""

# %%
"""
    is_known_mental_health_care: label encode the categories into:
    
    {
        'Yes': 1,
        'I'm not sure': 0.5,
        'No': 0
    }
"""

# %%
"""
    has_formally_mental_health_discussed_by_current_emp: label encode the categories into:
    
    {
        'Yes': 1,
        'I'm not sure': 0.5,
        'No': 0
    }
"""

# %%
"""
    is_mental_health_resource_offered_by_current_emp: label encode the categories into:
    
    {
        'Yes': 1,
        'I'm not sure': 0.5,
        'No': 0
    }
"""

# %%
"""
    would_anonymity_be_protected_by_current_emp: label encode the categories into:
    
    {
        'Yes': 1,
        'I'm not sure': 0.5,
        'No': 0
    }
"""

# %%
"""
    how_easy_to_ask_for_medical_leave: label encode the categories into:
    
    {
        'Very easy': 0,
        'Somewhat easy: 0.25,
        'Neither easy nor difficult': 0.5,
        'I don't know': 0.5
        'Somewhat difficult': 0.75
        'Very difficult': 1
    }
"""

# %%
"""
    would_discuss_mental_health_disorder_negative_consequences_with_current_emp: label encode the categories into:
    
    {
        'Yes': 1,
        'Maybe': 0.5,
        'No': 0
    }
"""

# %%
"""
    would_discuss_physical_health_disorder_with_current_emp: label encode the categories into:
    
    {
        'Yes': 1,
        'Maybe': 0.5,
        'No': 0
    }
"""

# %%
"""
    would_feel_comfortable_to_discuss_mental_health_with_current_coworker: label encode the categories into:
    
    {
        'Yes': 1,
        'Maybe': 0.5,
        'No': 0
    }
"""

# %%
"""
    would_feel_comfortable_to_discuss_mental_health_with_current_supervisor: label encode the categories into:
    
    {
        'Yes': 1,
        'Maybe': 0.5,
        'No': 0
    }
"""

# %%
"""
    would_mental_health_be_taken_seriously_by_emp: label encode the categories into:
    
    {
        'Yes': 1,
        'I don't know: 0.5,
        'No': 0
    }
"""

# %%
"""
    would_observe_negative_consequences_in_current_coworkers: label encode the categories into:
    
    {
        'Yes': 1,
        'No': 0
    }
"""

# %%
"""
    has_medical_coverage: label encode the categories into:
    
    {
        1146 nan,
        185 1,
        102 0
    }
"""

# %%
"""
    know_local_or_online_resources_for_help: label encode the categories into:
    
    {
        1146 nan,
        'I know some': 141,
        'Yes, I know several': 83,
        'No, I don't know any': 63
    }
"""

# %%
"""
    reveal_disorder_if_diagnosed_or_treated_to_clients_or_business_contact: label encode the categories into:
    
    {
        nan: 1146, 'Not applicable to me': 101, 'No, because it would impact me negatively': 83, 'Sometimes, if it comes up': 57, "No, because it doesn't matter": 44, 'Yes, always': 2
    }
"""

# %%
"""
    affected_negatively_if_reveled_to_client_or_business_contact
    
    {
        nan: 1289, "I'm not sure": 66, 'No': 42, 'Yes': 36
    }
"""

# %%
"""
    reveal_disorder_if_diagnosed_or_treated_to_coworker_or_employee

    
    {
        {nan: 1146, 'Not applicable to me': 111, 'Sometimes, if it comes up': 99, 'No, because it would impact me negatively': 51, "No, because it doesn't matter": 15, 'Yes, always': 11}
    }
"""

# %%
"""
    affected_negatively_if_revealed_to_coworker_or_employee

    
    {
        nan: 1146, 'Not applicable to me': 133, "I'm not sure": 62, 'No': 57, 'Yes': 35
    }
"""

# %%
"""
    
    productivity_affected_by_mental_health
    {
        {nan: 1146, 'Yes': 204, 'Unsure': 38, 'Not applicable to me': 31, 'No': 14}
    }
"""

# %%
"""
    
    percentage_of_worktime_affected_by_mental_health
    {
        {nan: 1229, '1-25%': 92, '26-50%': 72, '51-75%': 26, '76-100%': 14}
    }
"""

# %%
"""
    
    has_previous_employers

    {
        {1: 1264, 0: 169}
    }
"""

# %%
"""
    provided_mental_health_benefits_by_previous_employer: label encode the categories into:
    
    {
        'Yes, they all did': 1,
        'Some did': 0.5,
        'I don't know': 0.25,
        'No, none did': 0
    }
"""

# %%
"""
    aware_of_options_provided_by_previous_employer: label encode the categories into:
    
    {
        'Yes, they all did': 1,
        'Some did': 0.5,
        'I don't know': 0.25,
        'No, none did': 0
    }
"""

# %%
"""
    has_formally_discussed_mental_health_with_previous_employer: label encode the categories into:
    
    {
        'Yes': 1,
        'I don't know': 0.5,
        'No': 0
    }
"""

# %%
"""
    is_mental_health_resource_offered_by_previous_employer: label encode the categories into:
    
    {
        'Yes they all did': 1,
        'Some did': 0.5,
        'None did': 0
    }
"""

# %%
"""
    would_anonymity_protected_by_previous_employer: label encode the categories into:
    
    {
        'Always': 1,
        'Sometimes': 0.5,
        'Never': 0
    }
"""

# %%
"""
    
    would_discuss_mental_health_disorder_negative_consequences_with_previous_employer

    {
        {'Some of them': 615, "I don't know": 310, 'Yes, all of them': 226, nan: 169, 'None of them': 113}
    }
"""

# %%
"""
    would_discuss_physical_health_disorder_negative_consequences_with_previous_employer

    
    {
        {'Some of them': 631, 'None of them': 559, nan: 169, 'Yes, all of them': 74}
    }
"""

# %%
"""
    would_feel_comfortable_to_discuss_mental_health_with_previous_supervisor

    
    {
        {'Some of my previous employers': 654, 'No, at none of my previous employers': 416, nan: 169, "I don't know": 101, 'Yes, at all of my previous employers': 93}
    }
"""

# %%
"""
    would_mental_health_be_taken_seriously_by_previous_employer
{
    'None did': 463, 'Some did': 427, "I don't know": 331, nan: 169, 'Yes, they all did': 43
}
    
"""

# %%
"""
    
    would_observe_negative_consequences_in_previous_coworkers

    {
        {'None of them': 758, 'Some of them': 444, nan: 169, 'Yes, all of them': 62}
    }
"""

# %%
"""
    would_bring_up_physical_health_issue_in_interview
    {'Maybe': 633, 'No': 441, 'Yes': 359}
"""

# %%
"""physical_health_reason"""

# %%
# label encoding - employee number range
# employee number range - dividing the range into min / max columns

# is primary company tech - assign most frequent
#

# %% [markdown]
# ## Selecting X, y Datasets

# %%
# selecting y dataset
y = df[target]

# %%
# keep only numeric columns by checking the data type of each series
numeric_cols = [col for col in df.columns if type(df.loc[0, col]) is not str]        

# selecting X dataset
X = df[numeric_cols]

# %%
X.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# 1     1     1       3         4   5   5   6
# 2     2     3       3        10   7   8  10
# 3     1     1       5         2  15  14  15
# 4     1     2       5         4   6  10  10

# %% [markdown]
# ## Spliting the Datasets into Train/Test

# %%
# split the dataset set into 80% train and 20% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Building and Training the model

# %%
# building the decision tree classifier model
classifier_model = tree.DecisionTreeClassifier()

# %% [markdown]
# ## Training the model

# %%
classifier_model = classifier_model.fit(X_train, y_train)

# %% [markdown]
# ## Visualizing the Model

# %%
# improving the visualization with matplotlib and plot_tree function from scikitlearn
fig = plt.figure(figsize=(40,40))
_   = tree.plot_tree(classifier_model, feature_names=X.columns, filled=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9h/shtg41l15gv9smx901rw_l8w0000gn/T/ipykernel_85404/2723461909.py in <module>
#       1 # improving the visualization with matplotlib and plot_tree function from scikitlearn
# ----> 2 fig = plt.figure(figsize=(40,40))
#       3 _   = tree.plot_tree(classifier_model, feature_names=X.columns, filled=True)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Predicting the Result

# %%
preds = classifier_model.predict(X_test)
print(preds)
# Out:
# ['yes' 'yes' 'yes' 'yes' 'yes' 'yes' 'no' 'no' 'yes' 'yes' 'yes' 'no'
#  'yes' 'yes' 'yes' 'yes' 'no' 'yes' 'yes' 'yes' 'yes' 'yes' 'yes' 'yes'
#  'no' 'no' 'yes' 'yes' 'yes' 'yes' 'yes' 'no' 'yes' 'yes' 'yes' 'no' 'no'
#  'yes' 'yes' 'no' 'yes' 'yes' 'no' 'no' 'no' 'yes' 'yes' 'yes' 'yes' 'yes'
#  'yes' 'yes' 'no' 'yes' 'yes' 'yes' 'yes' 'yes' 'no' 'yes' 'no' 'yes'
#  'yes' 'no' 'yes' 'yes' 'yes' 'yes' 'yes' 'yes' 'no' 'no' 'yes' 'no' 'yes'
#  'yes' 'yes' 'yes' 'yes']

# %% [markdown]
# ## Forming Accuracy Test on the Prediction

# %%
print(accuracy_score(y_test, preds))
# Out:
# 0.5822784810126582

# %% [markdown]
# ## Calculating Feature Importances

# %% [markdown]
# The code below uses the Gini importance score to calculate the importance of each feature for the final result.
#
# Gini importance is computed as the sum of the number of splits where the feature was used divided by the total number of samples resulting in each split. The higher the score, the more important the feature.

# %%
# sorting the feature importances in ascending order and printing in column-score relationship
for col, score in sorted(zip(X.columns, classifier_model.feature_importances_), key=lambda x: x[1]):
    print(f'Column: {col}\t\tScore: {score}')
# Out:
# Column: failures		Score: 0.0
# Column: Walc		Score: 0.021830393568734667
# Column: Fedu		Score: 0.024958597671278244
# Column: health		Score: 0.030479393469533336
# Column: Dalc		Score: 0.036230222426049064
# Column: traveltime		Score: 0.04406315481819117
# Column: famrel		Score: 0.05707199964495038
# Column: age		Score: 0.058336982916624786
# Column: freetime		Score: 0.06435374277477364
# Column: G1		Score: 0.07070965618812751
# Column: Medu		Score: 0.07543913635231589
# Column: goout		Score: 0.07696146003280555
# Column: studytime		Score: 0.09422180280928273
# Column: absences		Score: 0.09941710969223419
# Column: G3		Score: 0.11255973014105664
# Column: G2		Score: 0.13336661749404222

# %% [markdown]
# #

# %% [markdown]
# ## Visualizing the Model

# %% [markdown]
# ## NOTE:
#
# In the code above, we've performed the splitting and modelling processes in order to get the same reproducible result for each run, ``random_state`` parameter has been changed from ``None`` to `42` in each call.
